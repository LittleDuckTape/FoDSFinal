# %%
# day 1 - data handling & cleaning

# %%
#imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import os

# %%
#to check directory
os.getcwd()
# Out:
# 'c:\\Users\\Irene\\Desktop\\School\\BINUS\\Semester 3\\Data Science\\Final Project\\short_video_academic_study\\notebooks'

# %%
df = pd.read_excel("../data/Data Responden Artikel Ilmiah Callista dan Alexandra.xlsx")
df.head()
# Out:
#   Nama  Jenis Kelamin  Usia Jenjang Pendidikan  \
# 0    AL     Laki-laki    21          Mahasiswa
# 1     A     Perempuan    19          Mahasiswa
# 2    AA     Laki-laki    18            SMA/SMK
# 3    AA     Laki-laki    20          Mahasiswa
# 4  FA       Perempuan    21          Mahasiswa
#
#    1. Saya menonton TikTok setiap hari.    \
# 0                                       3
# 1                                       3
# 2                                       4
# 3                                       4
# 4                                       4
#
#    2. Saya tidak bisa mengontrol waktu yang saya habiskan di TikTok.  \
# 0                                                  1
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    3. Saya sering menonton TikTok dalam waktu lama tanpa sadar.    \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  2
#
#    4. Saya membuka Tiktok lebih dari sekali dalam sehari  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    5. Saya lebih memilih TikTok karena konten yang bervariasi  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    6. Saya suka dengan konten di Tiktok karena durasi pendek dan visual menarik  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    16. Saya perlu waktu lama untuk kembali fokus belajar setelah terdistraksi oleh Tiktok.   \
# 0                                                  1
# 1                                                  3
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    17. Saya sulit mempertahankan perhatian saat membaca materi.  \
# 0                                                  2
# 1                                                  4
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    18. Saya suka mencari ringkasan materi karena malas membaca text yang panjang.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    19. Saya mudah memahami materi pembelajaran.    \
# 0                                               4
# 1                                               2
# 2                                               4
# 3                                               4
# 4                                               4
#
#    20. Saya mudah mengingat materi yang telah saya pelajarin.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    21. Saya selalu menyelesaikan tugas akademik sebelum melakukan aktivitas lain.   \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    22. Saya merasa hasil akademik saya memuaskan.   \
# 0                                                4
# 1                                                2
# 2                                                4
# 3                                                4
# 4                                                4
#
#    23. Saya memahami apa yang saya pelajari dari tugas yang diberikan.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    24. Saya mampu mengelola waktu belajar dengan baik.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    25. Saya rutin mempersiapkan diri untuk ujian/kuis.
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 29 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Nama                                                                                      150 non-null    object
#  1   Jenis Kelamin                                                                             150 non-null    object
#  2   Usia                                                                                      150 non-null    int64
#  3   Jenjang Pendidikan                                                                        150 non-null    object
#  4   1. Saya menonton TikTok setiap hari.                                                      150 non-null    int64
#  5   2. Saya tidak bisa mengontrol waktu yang saya habiskan di TikTok.                         150 non-null    int64
#  6   3. Saya sering menonton TikTok dalam waktu lama tanpa sadar.                              150 non-null    int64
#  7   4. Saya membuka Tiktok lebih dari sekali dalam sehari                                     150 non-null    int64
#  8   5. Saya lebih memilih TikTok karena konten yang bervariasi                                150 non-null    int64
#  9   6. Saya suka dengan konten di Tiktok karena durasi pendek dan visual menarik              150 non-null    int64
#  10  7.  Saya merasa sulit memahami materi yang memiliki banyak informasi kompleks.            150 non-null    int64
#  11  8. Saya sering membuka TikTok saat belajar.                                               150 non-null    int64
#  12  9. Saya mengalami kesulitan untuk kembali belajar setelah menonton TikTok.                150 non-null    int64
#  13  10. Saya merasa cepat lelah saat memproses informasi baru.                                150 non-null    int64
#  14  11. Saya sering kewalahan ketika harus membaca teks panjang.                              150 non-null    int64
#  15  12. Saya merasa butuh waktu ekstra untuk memahami pelajaran.                              150 non-null    int64
#  16  13. Saya sulit fokus saat memulai sesi belajar.                                           150 non-null    int64
#  17  14. Saya sering susah fokus jika belajar dalam waktu lama.                                150 non-null    int64
#  18  15. Saya sering berhenti mengerjakan tugas untuk membuka TikTok.                          150 non-null    int64
#  19  16. Saya perlu waktu lama untuk kembali fokus belajar setelah terdistraksi oleh Tiktok.   150 non-null    int64
#  20  17. Saya sulit mempertahankan perhatian saat membaca materi.                              150 non-null    int64
#  21  18. Saya suka mencari ringkasan materi karena malas membaca text yang panjang.            150 non-null    int64
#  22  19. Saya mudah memahami materi pembelajaran.                                              150 non-null    int64
#  23  20. Saya mudah mengingat materi yang telah saya pelajarin.                                150 non-null    int64
#  24  21. Saya selalu menyelesaikan tugas akademik sebelum melakukan aktivitas lain.            150 non-null    int64
#  25  22. Saya merasa hasil akademik saya memuaskan.                                            150 non-null    int64
#  26  23. Saya memahami apa yang saya pelajari dari tugas yang diberikan.                       150 non-null    int64
#  27  24. Saya mampu mengelola waktu belajar dengan baik.                                       150 non-null    int64
#  28  25. Saya rutin mempersiapkan diri untuk ujian/kuis.                                       150 non-null    int64
# dtypes: int64(26), object(3)
# memory usage: 34.1+ KB

# %%
list(df.columns)
# Out:
# ['Nama ',
#  'Jenis Kelamin',
#  'Usia',
#  'Jenjang Pendidikan',
#  '1. Saya menonton TikTok setiap hari.  ',
#  '2. Saya tidak bisa mengontrol waktu yang saya habiskan di TikTok.',
#  '3. Saya sering menonton TikTok dalam waktu lama tanpa sadar.  ',
#  '4. Saya membuka Tiktok lebih dari sekali dalam sehari',
#  '5. Saya lebih memilih TikTok karena konten yang bervariasi',
#  '6. Saya suka dengan konten di Tiktok karena durasi pendek dan visual menarik',
#  '7.  Saya merasa sulit memahami materi yang memiliki banyak informasi kompleks.  ',
#  '8. Saya sering membuka TikTok saat belajar. ',
#  '9. Saya mengalami kesulitan untuk kembali belajar setelah menonton TikTok. ',
#  '10. Saya merasa cepat lelah saat memproses informasi baru.',
#  '11. Saya sering kewalahan ketika harus membaca teks panjang.',
#  '12. Saya merasa butuh waktu ekstra untuk memahami pelajaran.',
#  '13. Saya sulit fokus saat memulai sesi belajar.  ',
#  '14. Saya sering susah fokus jika belajar dalam waktu lama. ',
#  '15. Saya sering berhenti mengerjakan tugas untuk membuka TikTok. ',
#  '16. Saya perlu waktu lama untuk kembali fokus belajar setelah terdistraksi oleh Tiktok. ',
#  '17. Saya sulit mempertahankan perhatian saat membaca materi.',
#  '18. Saya suka mencari ringkasan materi karena malas membaca text yang panjang.',
#  '19. Saya mudah memahami materi pembelajaran.  ',
#  '20. Saya mudah mengingat materi yang telah saya pelajarin.',
#  '21. Saya selalu menyelesaikan tugas akademik sebelum melakukan aktivitas lain. ',
#  '22. Saya merasa hasil akademik saya memuaskan. ',
#  '23. Saya memahami apa yang saya pelajari dari tugas yang diberikan.',
#  '24. Saya mampu mengelola waktu belajar dengan baik.',
#  '25. Saya rutin mempersiapkan diri untuk ujian/kuis.']

# %%
#freezing data (for backup)
df.to_csv("../data/raw_data_backup.csv", index=False)

# %%
df = df.drop(columns=["Nama "], errors="ignore")

if "Jenis Kelamin" in df.columns:
    df["Jenis Kelamin"] = df["Jenis Kelamin"].astype(str).str.strip().str.capitalize()

# %%
#check missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Jenis Kelamin                                                                               0
# Usia                                                                                        0
# Jenjang Pendidikan                                                                          0
# 1. Saya menonton TikTok setiap hari.                                                        0
# 2. Saya tidak bisa mengontrol waktu yang saya habiskan di TikTok.                           0
# 3. Saya sering menonton TikTok dalam waktu lama tanpa sadar.                                0
# 4. Saya membuka Tiktok lebih dari sekali dalam sehari                                       0
# 5. Saya lebih memilih TikTok karena konten yang bervariasi                                  0
# 6. Saya suka dengan konten di Tiktok karena durasi pendek dan visual menarik                0
# 7.  Saya merasa sulit memahami materi yang memiliki banyak informasi kompleks.              0
# 8. Saya sering membuka TikTok saat belajar.                                                 0
# 9. Saya mengalami kesulitan untuk kembali belajar setelah menonton TikTok.                  0
# 10. Saya merasa cepat lelah saat memproses informasi baru.                                  0
# 11. Saya sering kewalahan ketika harus membaca teks panjang.                                0
# 12. Saya merasa butuh waktu ekstra untuk memahami pelajaran.                                0
# 13. Saya sulit fokus saat memulai sesi belajar.                                             0
# 14. Saya sering susah fokus jika belajar dalam waktu lama.                                  0
# 15. Saya sering berhenti mengerjakan tugas untuk membuka TikTok.                            0
# 16. Saya perlu waktu lama untuk kembali fokus belajar setelah terdistraksi oleh Tiktok.     0
# 17. Saya sulit mempertahankan perhatian saat membaca materi.                                0
# 18. Saya suka mencari ringkasan materi karena malas membaca text yang panjang.              0
# 19. Saya mudah memahami materi pembelajaran.                                                0
# 20. Saya mudah mengingat materi yang telah saya pelajarin.                                  0
# 21. Saya selalu menyelesaikan tugas akademik sebelum melakukan aktivitas lain.              0
# 22. Saya merasa hasil akademik saya memuaskan.                                              0
# 23. Saya memahami apa yang saya pelajari dari tugas yang diberikan.                         0
# 24. Saya mampu mengelola waktu belajar dengan baik.                                         0
# 25. Saya rutin mempersiapkan diri untuk ujian/kuis.                                         0
# dtype: int64

# %%
#save day 1 dataset
df.to_csv("../data/day1.csv", index=False)

# %%
#quick sanity EDA (age distribution) [NOT FOR PAPER]
sns.histplot(df['Usia'], kde=True)
plt.title("Age Distribution (Sanity Check)")
plt.show()

# %%
# day 2 - index construction & core analysis

# %%
df = pd.read_csv("../data/day1.csv")

#normalize column names
df.columns = df.columns.str.strip()

df.head()
# Out:
#   Jenis Kelamin  Usia Jenjang Pendidikan  \
# 0     Laki-laki    21          Mahasiswa
# 1     Perempuan    19          Mahasiswa
# 2     Laki-laki    18            SMA/SMK
# 3     Laki-laki    20          Mahasiswa
# 4     Perempuan    21          Mahasiswa
#
#    1. Saya menonton TikTok setiap hari.  \
# 0                                     3
# 1                                     3
# 2                                     4
# 3                                     4
# 4                                     4
#
#    2. Saya tidak bisa mengontrol waktu yang saya habiskan di TikTok.  \
# 0                                                  1
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    3. Saya sering menonton TikTok dalam waktu lama tanpa sadar.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  2
#
#    4. Saya membuka Tiktok lebih dari sekali dalam sehari  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    5. Saya lebih memilih TikTok karena konten yang bervariasi  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    6. Saya suka dengan konten di Tiktok karena durasi pendek dan visual menarik  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    7.  Saya merasa sulit memahami materi yang memiliki banyak informasi kompleks.  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    16. Saya perlu waktu lama untuk kembali fokus belajar setelah terdistraksi oleh Tiktok.  \
# 0                                                  1
# 1                                                  3
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    17. Saya sulit mempertahankan perhatian saat membaca materi.  \
# 0                                                  2
# 1                                                  4
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    18. Saya suka mencari ringkasan materi karena malas membaca text yang panjang.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    19. Saya mudah memahami materi pembelajaran.  \
# 0                                             4
# 1                                             2
# 2                                             4
# 3                                             4
# 4                                             4
#
#    20. Saya mudah mengingat materi yang telah saya pelajarin.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    21. Saya selalu menyelesaikan tugas akademik sebelum melakukan aktivitas lain.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    22. Saya merasa hasil akademik saya memuaskan.  \
# 0                                               4
# 1                                               2
# 2                                               4
# 3                                               4
# 4                                               4
#
#    23. Saya memahami apa yang saya pelajari dari tugas yang diberikan.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    24. Saya mampu mengelola waktu belajar dengan baik.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    25. Saya rutin mempersiapkan diri untuk ujian/kuis.
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
# [5 rows x 28 columns]

# %%
#exposure: Q1–Q6
exposure_cols = [col for col in df.columns if col.startswith(tuple(f"{i}." for i in range(1, 7)))]

#attention: Q7–Q18
attention_cols = [col for col in df.columns if col.startswith(tuple(f"{i}." for i in range(7, 19)))]

#academic: Q19–Q25
academic_cols = [col for col in df.columns if col.startswith(tuple(f"{i}." for i in range(19, 26)))]

#sanity check
len(exposure_cols), len(attention_cols), len(academic_cols)
# Out:
# (6, 12, 7)

# %%
df['Exposure_Index'] = df[exposure_cols].mean(axis=1)
df['Attention_Index'] = df[attention_cols].mean(axis=1)
df['Academic_Index'] = df[academic_cols].mean(axis=1)

df[['Exposure_Index', 'Attention_Index', 'Academic_Index']].describe()
# Out:
#        Exposure_Index  Attention_Index  Academic_Index
# count      150.000000       150.000000      150.000000
# mean         3.190000         2.782778        3.148571
# std          0.679965         0.736353        0.652848
# min          1.333333         1.416667        1.428571
# 25%          2.833333         2.104167        2.714286
# 50%          3.333333         2.916667        3.428571
# 75%          3.666667         3.500000        3.571429
# max          4.000000         3.750000        3.857143

# %%
#index distributions
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

sns.histplot(df['Exposure_Index'], kde=True, ax=axes[0])
axes[0].set_title("Exposure Index")

sns.histplot(df['Attention_Index'], kde=True, ax=axes[1])
axes[1].set_title("Attention Index")

sns.histplot(df['Academic_Index'], kde=True, ax=axes[2])
axes[2].set_title("Academic Performance Index")

plt.tight_layout()
plt.show()

# %%
#correlation analysis
corr = df[['Exposure_Index', 'Attention_Index', 'Academic_Index']].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Between Exposure, Attention, and Academic Performance")
plt.show()

corr
# Out:
#                  Exposure_Index  Attention_Index  Academic_Index
# Exposure_Index         1.000000         0.682821        0.561970
# Attention_Index        0.682821         1.000000        0.483422
# Academic_Index         0.561970         0.483422        1.000000

# %%
#mediation regression
#model a: exposure -> attention
X = sm.add_constant(df['Exposure_Index'])
y = df['Attention_Index']
model_a = sm.OLS(y, X).fit()
print(model_a.summary())

#model b: exposure -> academic
X = sm.add_constant(df['Exposure_Index'])
y = df['Academic_Index']
model_b = sm.OLS(y, X).fit()
print(model_b.summary())

#model c: attention -> academic
X = sm.add_constant(df['Attention_Index'])
y = df['Academic_Index']
model_c = sm.OLS(y, X).fit()
print(model_c.summary())

#model d: exposure + attention -> academic
X = sm.add_constant(df[['Exposure_Index', 'Attention_Index']])
y = df['Academic_Index']
model_d = sm.OLS(y, X).fit()
print(model_d.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Attention_Index   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     129.3
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           6.34e-22
# Time:                        13:29:17   Log-Likelihood:                -119.35
# No. Observations:                 150   AIC:                             242.7
# Df Residuals:                     148   BIC:                             248.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.4239      0.212      1.999      0.047       0.005       0.843
# Exposure_Index     0.7394      0.065     11.370      0.000       0.611       0.868
# ==============================================================================
# Omnibus:                        5.748   Durbin-Watson:                   1.745
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.739
# Skew:                          -0.479   Prob(JB):                       0.0567
# Kurtosis:                       2.963   Cond. No.                         17.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Academic_Index   R-squared:                       0.316
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     68.31
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           7.30e-14
# Time:                        13:29:17   Log-Likelihood:                -119.91
# No. Observations:                 150   AIC:                             243.8
# Df Residuals:                     148   BIC:                             249.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              1.4274      0.213      6.705      0.000       1.007       1.848
# Exposure_Index     0.5396      0.065      8.265      0.000       0.411       0.669
# ==============================================================================
# Omnibus:                       10.413   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.788
# Skew:                          -0.557   Prob(JB):                      0.00454
# Kurtosis:                       3.695   Cond. No.                         17.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Academic_Index   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     45.14
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           3.70e-10
# Time:                        13:29:17   Log-Likelihood:                -128.41
# No. Observations:                 150   AIC:                             260.8
# Df Residuals:                     148   BIC:                             266.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.9559      0.184     10.653      0.000       1.593       2.319
# Attention_Index     0.4286      0.064      6.718      0.000       0.303       0.555
# ==============================================================================
# Omnibus:                       17.290   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.634
# Skew:                          -0.799   Prob(JB):                     5.45e-05
# Kurtosis:                       3.766   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Academic_Index   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     36.93
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           1.01e-13
# Time:                        13:29:17   Log-Likelihood:                -117.84
# No. Observations:                 150   AIC:                             241.7
# Df Residuals:                     147   BIC:                             250.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.3572      0.214      6.356      0.000       0.935       1.779
# Exposure_Index      0.4171      0.088      4.717      0.000       0.242       0.592
# Attention_Index     0.1656      0.082      2.028      0.044       0.004       0.327
# ==============================================================================
# Omnibus:                       13.648   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.362
# Skew:                          -0.637   Prob(JB):                     0.000462
# Kurtosis:                       3.913   Cond. No.                         22.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#adding control variables (NEW)

#encode education levels numerically
df['Education_Num'] = df['Jenjang Pendidikan'].map({
    'SMA/SMK': 0,
    'Mahasiswa': 1
})

X = sm.add_constant(
    df[['Exposure_Index', 'Attention_Index', 'Usia', 'Education_Num']]
)
y = df['Academic_Index']

model_control = sm.OLS(y, X).fit()
print(model_control.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Academic_Index   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     18.41
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           2.96e-12
# Time:                        13:29:18   Log-Likelihood:                -117.57
# No. Observations:                 150   AIC:                             245.1
# Df Residuals:                     145   BIC:                             260.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.0359      0.607      1.707      0.090      -0.164       2.235
# Exposure_Index      0.4204      0.091      4.640      0.000       0.241       0.599
# Attention_Index     0.1609      0.083      1.929      0.056      -0.004       0.326
# Usia                0.0191      0.030      0.634      0.527      -0.040       0.079
# Education_Num      -0.0982      0.141     -0.695      0.488      -0.377       0.181
# ==============================================================================
# Omnibus:                       11.554   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.112
# Skew:                          -0.605   Prob(JB):                      0.00234
# Kurtosis:                       3.690   Cond. No.                         298.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#standardize (z-score) robustness check (NEW)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['Exposure_z', 'Attention_z', 'Academic_z']] = scaler.fit_transform(
    df[['Exposure_Index', 'Attention_Index', 'Academic_Index']]
)

X = sm.add_constant(df[['Exposure_z', 'Attention_z']])
y = df['Academic_z']

model_standardized = sm.OLS(y, X).fit()
print(model_standardized.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Academic_z   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     36.93
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           1.01e-13
# Time:                        13:29:18   Log-Likelihood:                -182.31
# No. Observations:                 150   AIC:                             370.6
# Df Residuals:                     147   BIC:                             379.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -6.297e-16      0.067  -9.36e-15      1.000      -0.133       0.133
# Exposure_z      0.4344      0.092      4.717      0.000       0.252       0.616
# Attention_z     0.1868      0.092      2.028      0.044       0.005       0.369
# ==============================================================================
# Omnibus:                       13.648   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.362
# Skew:                          -0.637   Prob(JB):                     0.000462
# Kurtosis:                       3.913   Cond. No.                         2.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#regression visuals (NEW)
scaler = StandardScaler()
df[['Exposure_z', 'Attention_z', 'Academic_z']] = scaler.fit_transform(
    df[['Exposure_Index', 'Attention_Index', 'Academic_Index']]
)

X = sm.add_constant(df[['Exposure_z', 'Attention_z']])
y = df['Academic_z']

model_standardized = sm.OLS(y, X).fit()
print(model_standardized.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Academic_z   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     36.93
# Date:                Sat, 03 Jan 2026   Prob (F-statistic):           1.01e-13
# Time:                        13:29:18   Log-Likelihood:                -182.31
# No. Observations:                 150   AIC:                             370.6
# Df Residuals:                     147   BIC:                             379.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -6.297e-16      0.067  -9.36e-15      1.000      -0.133       0.133
# Exposure_z      0.4344      0.092      4.717      0.000       0.252       0.616
# Attention_z     0.1868      0.092      2.028      0.044       0.005       0.369
# ==============================================================================
# Omnibus:                       13.648   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.362
# Skew:                          -0.637   Prob(JB):                     0.000462
# Kurtosis:                       3.913   Cond. No.                         2.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#cronbach’s alpha (reliability analysis)
def cronbach_alpha(df_items):
    items = df_items.to_numpy()
    item_variances = items.var(axis=0, ddof=1)
    total_variance = items.sum(axis=1).var(ddof=1)
    n_items = items.shape[1]
    return (n_items / (n_items - 1)) * (1 - item_variances.sum() / total_variance)

print("Exposure α:", cronbach_alpha(df[exposure_cols]))
print("Attention α:", cronbach_alpha(df[attention_cols]))
print("Academic α:", cronbach_alpha(df[academic_cols]))
# Out:
# Exposure α: 0.869695088022064
# Attention α: 0.9268659811784467
# Academic α: 0.9016519411665568

# %%
#save day2 dataset
df.to_csv("../data/day2.csv", index=False)

# %%
#final outputs
summary_table = pd.DataFrame({
    'Model': [
        'Exposure → Attention',
        'Exposure → Academic',
        'Attention → Academic',
        'Mediation (no controls)',
        'Mediation (with controls)'
    ],
    'R_squared': [
        model_a.rsquared,
        model_b.rsquared,
        model_c.rsquared,
        model_d.rsquared,
        model_control.rsquared
    ]
})

summary_table
# Out:
#                        Model  R_squared
# 0       Exposure → Attention   0.466244
# 1        Exposure → Academic   0.315810
# 2       Attention → Academic   0.233697
# 3    Mediation (no controls)   0.334432
# 4  Mediation (with controls)   0.336859

# %%
summary_table.to_csv("../data/model_summary_table.csv", index=False)

# %%
# day 3 - predictive modeling & evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
features = [
    "Exposure_Index",
    "Attention_Index",
    "Usia",
    "Education_Num"
]

#continuous target (regression)
target_reg = "Academic_Index"

X = df[features]
y = df[target_reg]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42
)

# %%
#regression model
reg_models = {
    "Linear Regression": LinearRegression(),
    "Random Forest Regressor": RandomForestRegressor(
        n_estimators=200,
        random_state=42
    )
}

reg_results = []

for name, model in reg_models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    reg_results.append({
        "Model": name,
        "Test_R2": r2_score(y_test, preds),
        "RMSE": np.sqrt(mean_squared_error(y_test, preds))
    })

reg_results_df = pd.DataFrame(reg_results)
print("Regression Model Performance:")
display(reg_results_df)
# Out:
# Regression Model Performance:
#                      Model   Test_R2      RMSE
# 0        Linear Regression  0.055264  0.636139
# 1  Random Forest Regressor  0.370828  0.519137

# %%
#classification target

#academic performance risk levels (low / medium / high)
df["Academic_Level"] = pd.qcut(
    df["Academic_Index"],
    q=3,
    labels=["Low", "Medium", "High"]
)

X_cls = df[features]
y_cls = df["Academic_Level"]

Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    X_cls,
    y_cls,
    test_size=0.25,
    random_state=42,
    stratify=y_cls
)

# %%
#classification model
cls_models = {
    "Logistic Regression": LogisticRegression(
        max_iter=1000,
        multi_class="multinomial"
    ),
    "Random Forest Classifier": RandomForestClassifier(
        n_estimators=300,
        random_state=42
    )
}

cls_results = []

for name, model in cls_models.items():
    model.fit(Xc_train, yc_train)
    preds = model.predict(Xc_test)

    cls_results.append({
        "Model": name,
        "Accuracy": accuracy_score(yc_test, preds)
    })

    print(f"\n{name} — Classification Report")
    print(classification_report(yc_test, preds))
    print("Confusion Matrix:")
    print(confusion_matrix(yc_test, preds))

cls_results_df = pd.DataFrame(cls_results)
print("\nClassification Model Performance:")
display(cls_results_df)
# Out:
# Logistic Regression — Classification Report
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00         6
#          Low       0.50      0.46      0.48        13
#       Medium       0.50      0.68      0.58        19
#
#     accuracy                           0.50        38
#    macro avg       0.33      0.38      0.35        38
# weighted avg       0.42      0.50      0.45        38
#
# Confusion Matrix:
# [[ 0  0  6]
#  [ 0  6  7]
#  [ 0  6 13]]
# c:\Users\Irene\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\Irene\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Irene\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Irene\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Random Forest Classifier — Classification Report
#               precision    recall  f1-score   support
#
#         High       0.25      0.17      0.20         6
#          Low       0.46      0.46      0.46        13
#       Medium       0.71      0.79      0.75        19
#
#     accuracy                           0.58        38
#    macro avg       0.48      0.47      0.47        38
# weighted avg       0.55      0.58      0.56        38
#
# Confusion Matrix:
# [[ 1  3  2]
#  [ 3  6  4]
#  [ 0  4 15]]
#
# Classification Model Performance:
#                       Model  Accuracy
# 0       Logistic Regression  0.500000
# 1  Random Forest Classifier  0.578947

# %%
#feature importance
rf_classifier = cls_models["Random Forest Classifier"]

feature_importance_df = pd.DataFrame({
    "Feature": features,
    "Importance": rf_classifier.feature_importances_
}).sort_values(by="Importance", ascending=False)

print("Random Forest Feature Importance:")
display(feature_importance_df)
# Out:
# Random Forest Feature Importance:
#            Feature  Importance
# 1  Attention_Index    0.490882
# 0   Exposure_Index    0.291076
# 2             Usia    0.189729
# 3    Education_Num    0.028314

# %%
reg_results_df.to_csv("../data/day3_regression_results.csv", index=False)
cls_results_df.to_csv("../data/day3_classification_results.csv", index=False)
feature_importance_df.to_csv("../data/day3_feature_importance.csv", index=False)

# %%
#day 4 - graphs

# %%
day2 = pd.read_csv("../data/day2.csv")
print("Shape:", day2.shape)
print("Columns:", list(day2.columns))
# Out:
# Shape: (150, 35)
# Columns: ['Jenis Kelamin', 'Usia', 'Jenjang Pendidikan', '1. Saya menonton TikTok setiap hari.', '2. Saya tidak bisa mengontrol waktu yang saya habiskan di TikTok.', '3. Saya sering menonton TikTok dalam waktu lama tanpa sadar.', '4. Saya membuka Tiktok lebih dari sekali dalam sehari', '5. Saya lebih memilih TikTok karena konten yang bervariasi', '6. Saya suka dengan konten di Tiktok karena durasi pendek dan visual menarik', '7.  Saya merasa sulit memahami materi yang memiliki banyak informasi kompleks.', '8. Saya sering membuka TikTok saat belajar.', '9. Saya mengalami kesulitan untuk kembali belajar setelah menonton TikTok.', '10. Saya merasa cepat lelah saat memproses informasi baru.', '11. Saya sering kewalahan ketika harus membaca teks panjang.', '12. Saya merasa butuh waktu ekstra untuk memahami pelajaran.', '13. Saya sulit fokus saat memulai sesi belajar.', '14. Saya sering susah fokus jika belajar dalam waktu lama.', '15. Saya sering berhenti mengerjakan tugas untuk membuka TikTok.', '16. Saya perlu waktu lama untuk kembali fokus belajar setelah terdistraksi oleh Tiktok.', '17. Saya sulit mempertahankan perhatian saat membaca materi.', '18. Saya suka mencari ringkasan materi karena malas membaca text yang panjang.', '19. Saya mudah memahami materi pembelajaran.', '20. Saya mudah mengingat materi yang telah saya pelajarin.', '21. Saya selalu menyelesaikan tugas akademik sebelum melakukan aktivitas lain.', '22. Saya merasa hasil akademik saya memuaskan.', '23. Saya memahami apa yang saya pelajari dari tugas yang diberikan.', '24. Saya mampu mengelola waktu belajar dengan baik.', '25. Saya rutin mempersiapkan diri untuk ujian/kuis.', 'Exposure_Index', 'Attention_Index', 'Academic_Index', 'Education_Num', 'Exposure_z', 'Attention_z', 'Academic_z']

# %%
def find_col(df, keywords):
    for col in df.columns:
        name = col.lower()
        if all(k in name for k in keywords):
            return col
    return None

exposure_col = find_col(day2, ["exposure"])
attention_col = find_col(day2, ["attention"])
academic_col = find_col(day2, ["academic"])

print("Detected index columns:")
print("Exposure:", exposure_col)
print("Attention:", attention_col)
print("Academic:", academic_col)

day2 = day2.rename(columns={
    exposure_col: "Exposure_Index",
    attention_col: "Attention_Index",
    academic_col: "Academic_Index"
})
# Out:
# Detected index columns:
# Exposure: Exposure_Index
# Attention: Attention_Index
# Academic: Academic_Index

# %%
plt.figure()
plt.hist(
    day2["Exposure_Index"],
    bins=10,
    edgecolor="black",
    linewidth=0.8
)
plt.xlabel("Exposure Index")
plt.ylabel("Frequency")
plt.title("Distribution of Short-Form Video Exposure")
plt.tight_layout()
plt.savefig("../figures/fig_exposure_distribution.png", dpi=300)
plt.show()

# %%
plt.figure()
plt.hist(
    day2["Attention_Index"],
    bins=10,
    edgecolor="black",
    linewidth=0.8
)
plt.xlabel("Attention Span Index (higher = lower attention)")
plt.ylabel("Frequency")
plt.title("Distribution of Attention Span (Inverse Index)")
plt.tight_layout()
plt.savefig("../figures/fig_attention_distribution.png", dpi=300)
plt.show()

# %%
plt.figure()
plt.hist(
    day2["Academic_Index"],
    bins=10,
    edgecolor="black",
    linewidth=0.8
)
plt.xlabel("Academic Performance Index")
plt.ylabel("Frequency")
plt.title("Distribution of Academic Performance")
plt.tight_layout()
plt.savefig("../figures/fig_academic_distribution.png", dpi=300)
plt.show()

# %%
plt.figure()
sns.regplot(
    x=day2["Exposure_Index"],
    y=day2["Attention_Index"],
    scatter_kws={"alpha": 0.6},
    line_kws={"color": "black", "linewidth": 1}
)
plt.xlabel("Exposure Index")
plt.ylabel("Attention Span Index (higher = lower attention)")
plt.title("Relationship Between Short-Form Video Exposure and Attention Span")
plt.tight_layout()
plt.savefig("../figures/fig_exposure_attention.png", dpi=300)
plt.show()

# %%
plt.figure()
sns.regplot(
    x=day2["Attention_Index"],
    y=day2["Academic_Index"],
    scatter_kws={"alpha": 0.6},
    line_kws={"color": "black", "linewidth": 1}
)
plt.xlabel("Attention Span Index (higher = lower attention)")
plt.ylabel("Academic Performance Index")
plt.title("Relationship Between Attention Span and Academic Performance")
plt.tight_layout()
plt.savefig("../figures/fig_attention_academic.png", dpi=300)
plt.show()

# %%
feat_imp = pd.read_csv("../data/day3_feature_importance.csv")

print("Feature importance columns:", list(feat_imp.columns))

def find_feat_col(df):
    for col in df.columns:
        if "feature" in col.lower() or "variable" in col.lower():
            return col
    return None

def find_imp_col(df):
    for col in df.columns:
        name = col.lower()
        if "importance" in name or "score" in name or "gain" in name:
            return col
    return None

feature_col = find_feat_col(feat_imp)
importance_col = find_imp_col(feat_imp)

if not feature_col or not importance_col:
    raise ValueError("could not detect feature/importance columns")

feat_imp = feat_imp.rename(columns={
    feature_col: "Feature",
    importance_col: "Importance"
})

feat_imp = feat_imp.sort_values(by="Importance", ascending=True)

plt.figure()
plt.barh(
    feat_imp["Feature"],
    feat_imp["Importance"],
    edgecolor="black"
)
plt.xlabel("Feature Importance Score")
plt.title("Feature Importance for Academic Performance Prediction")
plt.tight_layout()
plt.savefig("../figures/fig_feature_importance.png", dpi=300)
plt.show()
# Out:
# Feature importance columns: ['Feature', 'Importance']

# %%
#optional
plt.figure()
sns.regplot(
    x=day2["Exposure_Index"],
    y=day2["Academic_Index"],
    scatter_kws={"alpha": 0.6},
    line_kws={"color": "black", "linewidth": 1}
)
plt.xlabel("Exposure Index")
plt.ylabel("Academic Performance Index")
plt.title("Direct Relationship Between Exposure and Academic Performance")
plt.tight_layout()
plt.savefig("../figures/fig_exposure_academic.png", dpi=300)
plt.show()
